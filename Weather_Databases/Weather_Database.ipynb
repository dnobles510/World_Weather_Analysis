# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.00, high=90.00, size=2000)
lngs = np.random.uniform(low=-180.00, high=180.00, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    #the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 748

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
city_url = url + "&q=" + city.replace(" ","+")
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4886b7273f273c59ab7b181d18b105f8&q=saint-philippe

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_winds = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City" : city.title(),
                         "Lat" : city_lat,
                         "Lng" : city_lng,
                         "Max Temp" : city_max_temp,
                         "Humidity" : city_humidity,
                         "Cloudiness" : city_clouds,
                         "Wind Speed" : city_winds,
                         "Country" : city_country,
                         "Weather Description" : city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | duki
# Processing Record 2 of Set 1 | provideniya
# Processing Record 3 of Set 1 | kaeo
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | sola
# Processing Record 6 of Set 1 | shimoda
# Processing Record 7 of Set 1 | zabol
# Processing Record 8 of Set 1 | jiangyou
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | klaksvik
# Processing Record 14 of Set 1 | tevriz
# Processing Record 15 of Set 1 | carnarvon
# Processing Record 16 of Set 1 | faanui
# Processing Record 17 of Set 1 | atar
# Processing Record 18 of Set 1 | aitape
# Processing Record 19 of Set 1 | college
# Processing Record 20 of Set 1 | trairi
# Processing Record 21 of Set 1 | nestorion
# City not found. Skipping...
# Processing Record 22 of Set 1 | manama
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | san miguel
# Processing Record 25 of Set 1 | north bend
# Processing Record 26 of Set 1 | pangnirtung
# Processing Record 27 of Set 1 | barhi
# Processing Record 28 of Set 1 | paamiut
# Processing Record 29 of Set 1 | vestmannaeyjar
# Processing Record 30 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 1 | kalmunai
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | harper
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | nantucket
# Processing Record 36 of Set 1 | wukari
# Processing Record 37 of Set 1 | sao felix do xingu
# Processing Record 38 of Set 1 | namibe
# Processing Record 39 of Set 1 | tuktoyaktuk
# Processing Record 40 of Set 1 | sao gabriel da cachoeira
# Processing Record 41 of Set 1 | buba
# Processing Record 42 of Set 1 | del rio
# Processing Record 43 of Set 1 | viedma
# Processing Record 44 of Set 1 | isangel
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | venado tuerto
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | morant bay
# Processing Record 49 of Set 1 | mar del plata
# Processing Record 50 of Set 1 | lasa
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | ilulissat
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | butaritari
# Processing Record 5 of Set 2 | dali
# Processing Record 6 of Set 2 | baykit
# Processing Record 7 of Set 2 | gravdal
# Processing Record 8 of Set 2 | kalengwa
# Processing Record 9 of Set 2 | marzuq
# Processing Record 10 of Set 2 | bam
# Processing Record 11 of Set 2 | nikolskoye
# Processing Record 12 of Set 2 | beringovskiy
# Processing Record 13 of Set 2 | vila velha
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | rikitea
# Processing Record 16 of Set 2 | port hardy
# Processing Record 17 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 2 | saskylakh
# Processing Record 23 of Set 2 | skarnes
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | lebu
# Processing Record 26 of Set 2 | susanville
# Processing Record 27 of Set 2 | cinisi
# Processing Record 28 of Set 2 | nanortalik
# Processing Record 29 of Set 2 | nemuro
# Processing Record 30 of Set 2 | new norfolk
# Processing Record 31 of Set 2 | pitimbu
# Processing Record 32 of Set 2 | cairns
# Processing Record 33 of Set 2 | vaini
# Processing Record 34 of Set 2 | waitati
# Processing Record 35 of Set 2 | topsham
# Processing Record 36 of Set 2 | cape town
# Processing Record 37 of Set 2 | mahibadhoo
# Processing Record 38 of Set 2 | itoman
# Processing Record 39 of Set 2 | olinda
# Processing Record 40 of Set 2 | erenhot
# Processing Record 41 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 2 | narsaq
# Processing Record 43 of Set 2 | miri
# Processing Record 44 of Set 2 | werda
# Processing Record 45 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | guarenas
# Processing Record 48 of Set 2 | sao filipe
# Processing Record 49 of Set 2 | airai
# Processing Record 50 of Set 2 | severo-kurilsk
# Processing Record 1 of Set 3 | deputatskiy
# Processing Record 2 of Set 3 | altay
# Processing Record 3 of Set 3 | sitka
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | chiredzi
# Processing Record 6 of Set 3 | homer
# Processing Record 7 of Set 3 | arraial do cabo
# Processing Record 8 of Set 3 | asau
# Processing Record 9 of Set 3 | fortuna
# Processing Record 10 of Set 3 | thompson
# Processing Record 11 of Set 3 | hirara
# Processing Record 12 of Set 3 | saint-philippe
# Processing Record 13 of Set 3 | letlhakeng
# Processing Record 14 of Set 3 | totma
# Processing Record 15 of Set 3 | bilma
# Processing Record 16 of Set 3 | umm lajj
# Processing Record 17 of Set 3 | tabou
# Processing Record 18 of Set 3 | rio grande
# Processing Record 19 of Set 3 | yellowknife
# Processing Record 20 of Set 3 | barrow
# Processing Record 21 of Set 3 | bluff
# Processing Record 22 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 23 of Set 3 | hithadhoo
# Processing Record 24 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 3 | montijo
# Processing Record 27 of Set 3 | saint george
# Processing Record 28 of Set 3 | torbay
# Processing Record 29 of Set 3 | mahebourg
# Processing Record 30 of Set 3 | khasan
# Processing Record 31 of Set 3 | sur
# Processing Record 32 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 3 | kampen
# Processing Record 34 of Set 3 | dunedin
# Processing Record 35 of Set 3 | hvide sande
# Processing Record 36 of Set 3 | sugod
# Processing Record 37 of Set 3 | guerrero negro
# Processing Record 38 of Set 3 | bubaque
# Processing Record 39 of Set 3 | luderitz
# Processing Record 40 of Set 3 | mount gambier
# Processing Record 41 of Set 3 | puerto escondido
# Processing Record 42 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 3 | qaanaaq
# Processing Record 44 of Set 3 | hofn
# Processing Record 45 of Set 3 | sembe
# Processing Record 46 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 3 | sanford
# Processing Record 48 of Set 3 | boddam
# Processing Record 49 of Set 3 | kahului
# Processing Record 50 of Set 3 | makakilo city
# Processing Record 1 of Set 4 | milyutinskaya
# Processing Record 2 of Set 4 | chokurdakh
# Processing Record 3 of Set 4 | praia da vitoria
# Processing Record 4 of Set 4 | san cristobal
# Processing Record 5 of Set 4 | te anau
# Processing Record 6 of Set 4 | kodiak
# Processing Record 7 of Set 4 | batemans bay
# Processing Record 8 of Set 4 | laguna
# Processing Record 9 of Set 4 | tchibanga
# Processing Record 10 of Set 4 | henties bay
# Processing Record 11 of Set 4 | kieta
# Processing Record 12 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 4 | kavieng
# Processing Record 14 of Set 4 | westport
# Processing Record 15 of Set 4 | ariquemes
# Processing Record 16 of Set 4 | buala
# Processing Record 17 of Set 4 | tanete
# Processing Record 18 of Set 4 | husavik
# Processing Record 19 of Set 4 | bethel
# Processing Record 20 of Set 4 | cockburn town
# Processing Record 21 of Set 4 | charters towers
# Processing Record 22 of Set 4 | lerwick
# Processing Record 23 of Set 4 | kodinsk
# Processing Record 24 of Set 4 | castro
# Processing Record 25 of Set 4 | bull savanna
# Processing Record 26 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 4 | hare bay
# Processing Record 28 of Set 4 | hushitai
# Processing Record 29 of Set 4 | trincomalee
# Processing Record 30 of Set 4 | sunndalsora
# Processing Record 31 of Set 4 | san carlos de bariloche
# Processing Record 32 of Set 4 | erdenet
# Processing Record 33 of Set 4 | baracoa
# Processing Record 34 of Set 4 | la plata
# Processing Record 35 of Set 4 | cabo san lucas
# Processing Record 36 of Set 4 | harur
# Processing Record 37 of Set 4 | flin flon
# Processing Record 38 of Set 4 | beyla
# Processing Record 39 of Set 4 | bilibino
# Processing Record 40 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 41 of Set 4 | kuala krai
# City not found. Skipping...
# Processing Record 42 of Set 4 | dakar
# Processing Record 43 of Set 4 | sept-iles
# Processing Record 44 of Set 4 | constitucion
# Processing Record 45 of Set 4 | port blair
# Processing Record 46 of Set 4 | soe
# Processing Record 47 of Set 4 | zhigansk
# Processing Record 48 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 4 | dingle
# Processing Record 50 of Set 4 | east london
# Processing Record 1 of Set 5 | kingaroy
# Processing Record 2 of Set 5 | belmonte
# Processing Record 3 of Set 5 | ixtapa
# Processing Record 4 of Set 5 | esperance
# Processing Record 5 of Set 5 | clyde river
# Processing Record 6 of Set 5 | santa cruz
# Processing Record 7 of Set 5 | fare
# Processing Record 8 of Set 5 | erzin
# Processing Record 9 of Set 5 | mount isa
# Processing Record 10 of Set 5 | hays
# Processing Record 11 of Set 5 | skegness
# Processing Record 12 of Set 5 | kutum
# Processing Record 13 of Set 5 | atuona
# Processing Record 14 of Set 5 | byron bay
# Processing Record 15 of Set 5 | qaqortoq
# Processing Record 16 of Set 5 | aykhal
# Processing Record 17 of Set 5 | leningradskiy
# Processing Record 18 of Set 5 | pskov
# Processing Record 19 of Set 5 | tasiilaq
# Processing Record 20 of Set 5 | cristobal obregon
# Processing Record 21 of Set 5 | yulara
# Processing Record 22 of Set 5 | kuito
# Processing Record 23 of Set 5 | aktau
# Processing Record 24 of Set 5 | samarinda
# Processing Record 25 of Set 5 | guangyuan
# Processing Record 26 of Set 5 | jeremie
# Processing Record 27 of Set 5 | takoradi
# Processing Record 28 of Set 5 | kpandae
# Processing Record 29 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 30 of Set 5 | roma
# Processing Record 31 of Set 5 | san quintin
# Processing Record 32 of Set 5 | dharchula
# Processing Record 33 of Set 5 | abyek
# Processing Record 34 of Set 5 | necochea
# Processing Record 35 of Set 5 | dandong
# Processing Record 36 of Set 5 | cherskiy
# Processing Record 37 of Set 5 | xining
# Processing Record 38 of Set 5 | boende
# Processing Record 39 of Set 5 | bengkulu
# Processing Record 40 of Set 5 | rock sound
# Processing Record 41 of Set 5 | humaita
# Processing Record 42 of Set 5 | mosjoen
# Processing Record 43 of Set 5 | port-cartier
# Processing Record 44 of Set 5 | havelock
# Processing Record 45 of Set 5 | carballo
# Processing Record 46 of Set 5 | rodental
# Processing Record 47 of Set 5 | bambous virieux
# Processing Record 48 of Set 5 | langcangan
# Processing Record 49 of Set 5 | khatanga
# Processing Record 50 of Set 5 | gushikawa
# Processing Record 1 of Set 6 | cayeli
# Processing Record 2 of Set 6 | voi
# Processing Record 3 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 6 | nuuk
# Processing Record 5 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 6 | asyut
# Processing Record 7 of Set 6 | chuy
# Processing Record 8 of Set 6 | great falls
# Processing Record 9 of Set 6 | batagay-alyta
# Processing Record 10 of Set 6 | westpunt
# City not found. Skipping...
# Processing Record 11 of Set 6 | ternate
# Processing Record 12 of Set 6 | tongling
# Processing Record 13 of Set 6 | gorkovskoye
# City not found. Skipping...
# Processing Record 14 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 15 of Set 6 | nishihara
# Processing Record 16 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 6 | mantua
# Processing Record 18 of Set 6 | waipawa
# Processing Record 19 of Set 6 | berlevag
# Processing Record 20 of Set 6 | whitehorse
# Processing Record 21 of Set 6 | wamba
# Processing Record 22 of Set 6 | axim
# Processing Record 23 of Set 6 | tari
# Processing Record 24 of Set 6 | muroto
# Processing Record 25 of Set 6 | suntar
# Processing Record 26 of Set 6 | coihaique
# Processing Record 27 of Set 6 | padang
# Processing Record 28 of Set 6 | khandyga
# Processing Record 29 of Set 6 | yar-sale
# Processing Record 30 of Set 6 | hualmay
# Processing Record 31 of Set 6 | novo aripuana
# Processing Record 32 of Set 6 | dikson
# Processing Record 33 of Set 6 | concepcion
# Processing Record 34 of Set 6 | lazaro cardenas
# Processing Record 35 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 36 of Set 6 | norman wells
# Processing Record 37 of Set 6 | bathsheba
# Processing Record 38 of Set 6 | alamos
# Processing Record 39 of Set 6 | itigi
# Processing Record 40 of Set 6 | benin
# Processing Record 41 of Set 6 | port elizabeth
# Processing Record 42 of Set 6 | verkh-usugli
# Processing Record 43 of Set 6 | merauke
# Processing Record 44 of Set 6 | kruisfontein
# Processing Record 45 of Set 6 | ahipara
# Processing Record 46 of Set 6 | la ronge
# Processing Record 47 of Set 6 | shellbrook
# Processing Record 48 of Set 6 | port pirie
# Processing Record 49 of Set 6 | walvis bay
# Processing Record 50 of Set 6 | edd
# Processing Record 1 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 7 | kamenka
# Processing Record 3 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 4 of Set 7 | poum
# Processing Record 5 of Set 7 | kalomo
# City not found. Skipping...
# Processing Record 6 of Set 7 | souillac
# Processing Record 7 of Set 7 | amazar
# Processing Record 8 of Set 7 | ancud
# Processing Record 9 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 10 of Set 7 | lagoa
# Processing Record 11 of Set 7 | adrar
# Processing Record 12 of Set 7 | san patricio
# Processing Record 13 of Set 7 | kalabo
# Processing Record 14 of Set 7 | geraldton
# Processing Record 15 of Set 7 | sinnamary
# Processing Record 16 of Set 7 | aklavik
# Processing Record 17 of Set 7 | denpasar
# Processing Record 18 of Set 7 | halifax
# Processing Record 19 of Set 7 | ngama
# Processing Record 20 of Set 7 | nueva loja
# Processing Record 21 of Set 7 | bosobolo
# Processing Record 22 of Set 7 | sheridan
# Processing Record 23 of Set 7 | miraflores
# Processing Record 24 of Set 7 | oussouye
# Processing Record 25 of Set 7 | gorin
# Processing Record 26 of Set 7 | pevek
# Processing Record 27 of Set 7 | volot
# Processing Record 28 of Set 7 | warmbad
# Processing Record 29 of Set 7 | ponta do sol
# Processing Record 30 of Set 7 | kamaishi
# Processing Record 31 of Set 7 | maraa
# Processing Record 32 of Set 7 | acarau
# Processing Record 33 of Set 7 | alofi
# Processing Record 34 of Set 7 | tilichiki
# Processing Record 35 of Set 7 | bara
# Processing Record 36 of Set 7 | agadez
# Processing Record 37 of Set 7 | wajima
# Processing Record 38 of Set 7 | zhezkazgan
# Processing Record 39 of Set 7 | katsuura
# Processing Record 40 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 41 of Set 7 | grindavik
# Processing Record 42 of Set 7 | willmar
# Processing Record 43 of Set 7 | payson
# Processing Record 44 of Set 7 | labuhan
# Processing Record 45 of Set 7 | havre-saint-pierre
# Processing Record 46 of Set 7 | dauphin
# Processing Record 47 of Set 7 | kinablangan
# Processing Record 48 of Set 7 | karasjok
# Processing Record 49 of Set 7 | mareeba
# Processing Record 50 of Set 7 | guadalupe y calvo
# Processing Record 1 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 8 | bumba
# Processing Record 4 of Set 8 | san policarpo
# Processing Record 5 of Set 8 | grand gaube
# Processing Record 6 of Set 8 | torrington
# Processing Record 7 of Set 8 | thurso
# Processing Record 8 of Set 8 | rosamorada
# Processing Record 9 of Set 8 | gotsu
# Processing Record 10 of Set 8 | jian
# Processing Record 11 of Set 8 | pampa
# Processing Record 12 of Set 8 | nome
# Processing Record 13 of Set 8 | tarko-sale
# Processing Record 14 of Set 8 | marathon
# Processing Record 15 of Set 8 | pacasmayo
# Processing Record 16 of Set 8 | sahrak
# City not found. Skipping...
# Processing Record 17 of Set 8 | miandrivazo
# Processing Record 18 of Set 8 | vyartsilya
# Processing Record 19 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 8 | tautira
# Processing Record 21 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 8 | komsomolskiy
# Processing Record 23 of Set 8 | nyzhnya krynka
# Processing Record 24 of Set 8 | majene
# Processing Record 25 of Set 8 | lompoc
# Processing Record 26 of Set 8 | eyemouth
# Processing Record 27 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 28 of Set 8 | pacific grove
# Processing Record 29 of Set 8 | lethem
# Processing Record 30 of Set 8 | okhotsk
# Processing Record 31 of Set 8 | taoudenni
# Processing Record 32 of Set 8 | sisimiut
# Processing Record 33 of Set 8 | mangrol
# Processing Record 34 of Set 8 | carberry
# Processing Record 35 of Set 8 | vaitape
# Processing Record 36 of Set 8 | ostrovnoy
# Processing Record 37 of Set 8 | tarbagatay
# Processing Record 38 of Set 8 | viransehir
# Processing Record 39 of Set 8 | hasaki
# Processing Record 40 of Set 8 | sao joao da barra
# Processing Record 41 of Set 8 | florida
# Processing Record 42 of Set 8 | tiksi
# Processing Record 43 of Set 8 | abu dhabi
# Processing Record 44 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 45 of Set 8 | mount holly
# Processing Record 46 of Set 8 | kainantu
# Processing Record 47 of Set 8 | vao
# Processing Record 48 of Set 8 | atambua
# Processing Record 49 of Set 8 | iqaluit
# Processing Record 50 of Set 8 | sellye
# Processing Record 1 of Set 9 | yomitan
# City not found. Skipping...
# Processing Record 2 of Set 9 | kasempa
# Processing Record 3 of Set 9 | rio gallegos
# Processing Record 4 of Set 9 | inuvik
# Processing Record 5 of Set 9 | the valley
# Processing Record 6 of Set 9 | caraguatatuba
# Processing Record 7 of Set 9 | comendador
# Processing Record 8 of Set 9 | progreso
# Processing Record 9 of Set 9 | maryville
# Processing Record 10 of Set 9 | carandai
# Processing Record 11 of Set 9 | koungheul
# Processing Record 12 of Set 9 | maniwaki
# Processing Record 13 of Set 9 | flinders
# Processing Record 14 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 9 | smithers
# Processing Record 16 of Set 9 | benguela
# Processing Record 17 of Set 9 | kavaratti
# Processing Record 18 of Set 9 | katherine
# Processing Record 19 of Set 9 | tarakan
# Processing Record 20 of Set 9 | rondonopolis
# Processing Record 21 of Set 9 | gigmoto
# Processing Record 22 of Set 9 | xaxim
# Processing Record 23 of Set 9 | turukhansk
# Processing Record 24 of Set 9 | santa isabel
# Processing Record 25 of Set 9 | inhambane
# Processing Record 26 of Set 9 | hambantota
# Processing Record 27 of Set 9 | kuryk
# Processing Record 28 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 9 | teya
# Processing Record 30 of Set 9 | ternovka
# Processing Record 31 of Set 9 | yeppoon
# Processing Record 32 of Set 9 | zhicheng
# Processing Record 33 of Set 9 | bria
# Processing Record 34 of Set 9 | zeya
# Processing Record 35 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 36 of Set 9 | pisco
# Processing Record 37 of Set 9 | porbandar
# Processing Record 38 of Set 9 | ovalle
# Processing Record 39 of Set 9 | culfa
# Processing Record 40 of Set 9 | lenoir
# Processing Record 41 of Set 9 | baoning
# Processing Record 42 of Set 9 | tlahualilo
# City not found. Skipping...
# Processing Record 43 of Set 9 | aguililla
# Processing Record 44 of Set 9 | marawi
# Processing Record 45 of Set 9 | ilka
# City not found. Skipping...
# Processing Record 46 of Set 9 | najran
# Processing Record 47 of Set 9 | mazurivka
# Processing Record 48 of Set 9 | yaizu
# Processing Record 49 of Set 9 | shambu
# Processing Record 50 of Set 9 | along
# Processing Record 1 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 10 | balabac
# Processing Record 3 of Set 10 | ambilobe
# Processing Record 4 of Set 10 | somerset
# Processing Record 5 of Set 10 | bonavista
# Processing Record 6 of Set 10 | quatre cocos
# Processing Record 7 of Set 10 | mehamn
# Processing Record 8 of Set 10 | ponta delgada
# Processing Record 9 of Set 10 | grand-santi
# Processing Record 10 of Set 10 | brownsville
# Processing Record 11 of Set 10 | huarmey
# Processing Record 12 of Set 10 | saldanha
# Processing Record 13 of Set 10 | sidney
# Processing Record 14 of Set 10 | cumberland
# Processing Record 15 of Set 10 | mnogovershinnyy
# Processing Record 16 of Set 10 | farafangana
# Processing Record 17 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 18 of Set 10 | port lincoln
# Processing Record 19 of Set 10 | angoche
# Processing Record 20 of Set 10 | nouadhibou
# Processing Record 21 of Set 10 | ojinaga
# Processing Record 22 of Set 10 | tuatapere
# Processing Record 23 of Set 10 | omsukchan
# Processing Record 24 of Set 10 | san lawrenz
# Processing Record 25 of Set 10 | los llanos de aridane
# Processing Record 26 of Set 10 | la romana
# Processing Record 27 of Set 10 | leshukonskoye
# Processing Record 28 of Set 10 | beloha
# Processing Record 29 of Set 10 | kysyl-syr
# Processing Record 30 of Set 10 | lavrentiya
# Processing Record 31 of Set 10 | debre zeyit
# Processing Record 32 of Set 10 | wanning
# Processing Record 33 of Set 10 | hay river
# Processing Record 34 of Set 10 | djambala
# Processing Record 35 of Set 10 | pemberton
# Processing Record 36 of Set 10 | puranpur
# Processing Record 37 of Set 10 | prince rupert
# Processing Record 38 of Set 10 | iralaya
# Processing Record 39 of Set 10 | salalah
# Processing Record 40 of Set 10 | vilhena
# Processing Record 41 of Set 10 | shumikha
# Processing Record 42 of Set 10 | varadero
# Processing Record 43 of Set 10 | diu
# Processing Record 44 of Set 10 | portmore
# Processing Record 45 of Set 10 | port moresby
# Processing Record 46 of Set 10 | burgeo
# Processing Record 47 of Set 10 | qui nhon
# Processing Record 48 of Set 10 | raudeberg
# Processing Record 49 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 50 of Set 10 | karratha
# Processing Record 1 of Set 11 | chikoy
# City not found. Skipping...
# Processing Record 2 of Set 11 | victoria
# Processing Record 3 of Set 11 | kununurra
# Processing Record 4 of Set 11 | rocky mountain house
# Processing Record 5 of Set 11 | atherton
# Processing Record 6 of Set 11 | bayir
# Processing Record 7 of Set 11 | terrak
# Processing Record 8 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 11 | pringsewu
# Processing Record 10 of Set 11 | clovis
# Processing Record 11 of Set 11 | taltal
# Processing Record 12 of Set 11 | inongo
# Processing Record 13 of Set 11 | rumuruti
# Processing Record 14 of Set 11 | enshi
# Processing Record 15 of Set 11 | bridlington
# Processing Record 16 of Set 11 | meulaboh
# Processing Record 17 of Set 11 | faya
# Processing Record 18 of Set 11 | tabuk
# Processing Record 19 of Set 11 | gizo
# Processing Record 20 of Set 11 | mongo
# Processing Record 21 of Set 11 | villarrica
# Processing Record 22 of Set 11 | kaitangata
# Processing Record 23 of Set 11 | hyeres
# Processing Record 24 of Set 11 | krasnokamsk
# Processing Record 25 of Set 11 | kirovsk
# Processing Record 26 of Set 11 | yenagoa
# Processing Record 27 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 11 | santa helena de goias
# Processing Record 29 of Set 11 | hobyo
# Processing Record 30 of Set 11 | chenzhou
# Processing Record 31 of Set 11 | kirakira
# Processing Record 32 of Set 11 | guantanamo
# Processing Record 33 of Set 11 | carolina
# Processing Record 34 of Set 11 | cayenne
# Processing Record 35 of Set 11 | brae
# Processing Record 36 of Set 11 | manokwari
# Processing Record 37 of Set 11 | lakeville
# Processing Record 38 of Set 11 | son la
# Processing Record 39 of Set 11 | cidreira
# Processing Record 40 of Set 11 | roald
# Processing Record 41 of Set 11 | praia
# Processing Record 42 of Set 11 | puerto madryn
# Processing Record 43 of Set 11 | zhitikara
# City not found. Skipping...
# Processing Record 44 of Set 11 | constantine
# Processing Record 45 of Set 11 | fairbanks
# Processing Record 46 of Set 11 | sohag
# Processing Record 47 of Set 11 | estelle
# Processing Record 48 of Set 11 | gap
# Processing Record 49 of Set 11 | kota kinabalu
# Processing Record 50 of Set 11 | saqqez
# Processing Record 1 of Set 12 | northam
# Processing Record 2 of Set 12 | vila franca do campo
# Processing Record 3 of Set 12 | ossora
# Processing Record 4 of Set 12 | sambava
# Processing Record 5 of Set 12 | svetlogorsk
# Processing Record 6 of Set 12 | ciocarlia
# Processing Record 7 of Set 12 | waingapu
# Processing Record 8 of Set 12 | belturbet
# Processing Record 9 of Set 12 | goure
# Processing Record 10 of Set 12 | bozova
# Processing Record 11 of Set 12 | adre
# Processing Record 12 of Set 12 | katangli
# Processing Record 13 of Set 12 | moose jaw
# Processing Record 14 of Set 12 | balkhash
# Processing Record 15 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 12 | bangangte
# Processing Record 17 of Set 12 | port-gentil
# Processing Record 18 of Set 12 | sayansk
# Processing Record 19 of Set 12 | talnakh
# Processing Record 20 of Set 12 | bulungu
# Processing Record 21 of Set 12 | saint-leu
# Processing Record 22 of Set 12 | iwanai
# Processing Record 23 of Set 12 | bosaso
# Processing Record 24 of Set 12 | parker
# Processing Record 25 of Set 12 | kovur
# Processing Record 26 of Set 12 | hokitika
# Processing Record 27 of Set 12 | crepaja
# Processing Record 28 of Set 12 | shache
# Processing Record 29 of Set 12 | sibolga
# Processing Record 30 of Set 12 | banda aceh
# Processing Record 31 of Set 12 | leh
# Processing Record 32 of Set 12 | kutno
# Processing Record 33 of Set 12 | tete
# Processing Record 34 of Set 12 | plainview
# Processing Record 35 of Set 12 | singuilucan
# Processing Record 36 of Set 12 | chumikan
# Processing Record 37 of Set 12 | mongomo
# Processing Record 38 of Set 12 | daru
# Processing Record 39 of Set 12 | lorengau
# Processing Record 40 of Set 12 | zhangjiakou
# Processing Record 41 of Set 12 | turbat
# Processing Record 42 of Set 12 | nam tha
# City not found. Skipping...
# Processing Record 43 of Set 12 | aranos
# Processing Record 44 of Set 12 | gwadar
# Processing Record 45 of Set 12 | urumqi
# Processing Record 46 of Set 12 | vestmanna
# Processing Record 47 of Set 12 | zwedru
# Processing Record 48 of Set 12 | sulangan
# Processing Record 49 of Set 12 | chinsali
# Processing Record 50 of Set 12 | atchison
# Processing Record 1 of Set 13 | saint paul
# Processing Record 2 of Set 13 | shchelyayur
# City not found. Skipping...
# Processing Record 3 of Set 13 | coquimbo
# Processing Record 4 of Set 13 | kamyshin
# Processing Record 5 of Set 13 | nam phong
# Processing Record 6 of Set 13 | korla
# Processing Record 7 of Set 13 | aksarka
# Processing Record 8 of Set 13 | saint-augustin
# Processing Record 9 of Set 13 | solnechnyy
# Processing Record 10 of Set 13 | shubarshi
# Processing Record 11 of Set 13 | juneau
# Processing Record 12 of Set 13 | guelengdeng
# City not found. Skipping...
# Processing Record 13 of Set 13 | pravia
# Processing Record 14 of Set 13 | iroquois falls
# Processing Record 15 of Set 13 | bende
# Processing Record 16 of Set 13 | chapais
# Processing Record 17 of Set 13 | manaure
# Processing Record 18 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 19 of Set 13 | labuan
# Processing Record 20 of Set 13 | amapa
# Processing Record 21 of Set 13 | agadir
# Processing Record 22 of Set 13 | mojo
# Processing Record 23 of Set 13 | labrea
# Processing Record 24 of Set 13 | posse
# Processing Record 25 of Set 13 | killybegs
# Processing Record 26 of Set 13 | elat
# Processing Record 27 of Set 13 | upernavik
# Processing Record 28 of Set 13 | san ignacio
# Processing Record 29 of Set 13 | chabahar
# Processing Record 30 of Set 13 | san jose
# Processing Record 31 of Set 13 | gunjur
# Processing Record 32 of Set 13 | herat
# Processing Record 33 of Set 13 | aksay
# Processing Record 34 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 13 | cabedelo
# Processing Record 36 of Set 13 | morgan city
# Processing Record 37 of Set 13 | saint-joseph
# Processing Record 38 of Set 13 | plettenberg bay
# Processing Record 39 of Set 13 | kuala selangor
# Processing Record 40 of Set 13 | union
# Processing Record 41 of Set 13 | lata
# Processing Record 42 of Set 13 | alvand
# Processing Record 43 of Set 13 | tokur
# Processing Record 44 of Set 13 | ulaanbaatar
# Processing Record 45 of Set 13 | chihuahua
# Processing Record 46 of Set 13 | lianzhou
# Processing Record 47 of Set 13 | bar harbor
# Processing Record 48 of Set 13 | goderich
# Processing Record 49 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 50 of Set 13 | mayya
# Processing Record 1 of Set 14 | changtu
# Processing Record 2 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 14 | troitskoye
# Processing Record 4 of Set 14 | morehead
# Processing Record 5 of Set 14 | fort nelson
# Processing Record 6 of Set 14 | serebryanyy bor
# Processing Record 7 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 8 of Set 14 | nelson bay
# Processing Record 9 of Set 14 | launceston
# Processing Record 10 of Set 14 | camacupa
# Processing Record 11 of Set 14 | kenai
# Processing Record 12 of Set 14 | mamit
# Processing Record 13 of Set 14 | champerico
# Processing Record 14 of Set 14 | melong
# Processing Record 15 of Set 14 | tougue
# Processing Record 16 of Set 14 | peniche
# Processing Record 17 of Set 14 | shirokiy
# Processing Record 18 of Set 14 | tshane
# Processing Record 19 of Set 14 | makasar
# Processing Record 20 of Set 14 | ayagoz
# Processing Record 21 of Set 14 | ivanjica
# Processing Record 22 of Set 14 | hilpoltstein
# Processing Record 23 of Set 14 | muravlenko
# Processing Record 24 of Set 14 | vostok
# Processing Record 25 of Set 14 | severnyy
# Processing Record 26 of Set 14 | nicoya
# Processing Record 27 of Set 14 | kiunga
# Processing Record 28 of Set 14 | gouyave
# Processing Record 29 of Set 14 | mayumba
# Processing Record 30 of Set 14 | shangrao
# Processing Record 31 of Set 14 | haines junction
# Processing Record 32 of Set 14 | sosnovo-ozerskoye
# Processing Record 33 of Set 14 | bowen
# Processing Record 34 of Set 14 | rawson
# Processing Record 35 of Set 14 | biltine
# Processing Record 36 of Set 14 | codrington
# Processing Record 37 of Set 14 | ciudad bolivar
# Processing Record 38 of Set 14 | thunder bay
# Processing Record 39 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 40 of Set 14 | olafsvik
# Processing Record 41 of Set 14 | soto la marina
# Processing Record 42 of Set 14 | proddatur
# Processing Record 43 of Set 14 | yumen
# Processing Record 44 of Set 14 | ballina
# Processing Record 45 of Set 14 | markova
# Processing Record 46 of Set 14 | hastings
# Processing Record 47 of Set 14 | mitzic
# Processing Record 48 of Set 14 | kongwa
# Processing Record 49 of Set 14 | luwuk
# Processing Record 50 of Set 14 | wattegama
# Processing Record 1 of Set 15 | balotra
# Processing Record 2 of Set 15 | duluth
# Processing Record 3 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 4 of Set 15 | yanam
# Processing Record 5 of Set 15 | taseyevo
# Processing Record 6 of Set 15 | imeni babushkina
# Processing Record 7 of Set 15 | rafaela
# Processing Record 8 of Set 15 | verkhnyaya inta
# Processing Record 9 of Set 15 | sechura
# Processing Record 10 of Set 15 | lahaina
# Processing Record 11 of Set 15 | gobabis
# Processing Record 12 of Set 15 | bolshoy lug
# Processing Record 13 of Set 15 | el sauzal
# Processing Record 14 of Set 15 | rantepao
# Processing Record 15 of Set 15 | beruwala
# Processing Record 16 of Set 15 | tazovskiy
# Processing Record 17 of Set 15 | acapulco
# Processing Record 18 of Set 15 | bindura
# Processing Record 19 of Set 15 | arenapolis
# Processing Record 20 of Set 15 | narrabri
# Processing Record 21 of Set 15 | kondinskoye
# Processing Record 22 of Set 15 | parrita
# Processing Record 23 of Set 15 | egvekinot
# Processing Record 24 of Set 15 | iquique
# Processing Record 25 of Set 15 | leo
# Processing Record 26 of Set 15 | paramonga
# Processing Record 27 of Set 15 | luanda
# Processing Record 28 of Set 15 | yinchuan
# Processing Record 29 of Set 15 | severo-yeniseyskiy
# Processing Record 30 of Set 15 | dondaicha
# Processing Record 31 of Set 15 | bongor
# Processing Record 32 of Set 15 | dennery
# Processing Record 33 of Set 15 | saratovskaya
# Processing Record 34 of Set 15 | los banos
# Processing Record 35 of Set 15 | richards bay
# Processing Record 36 of Set 15 | parkes
# Processing Record 37 of Set 15 | belaya gora
# Processing Record 38 of Set 15 | slave lake
# Processing Record 39 of Set 15 | ondjiva
# Processing Record 40 of Set 15 | coahuayana
# Processing Record 41 of Set 15 | kashan
# Processing Record 42 of Set 15 | changping
# Processing Record 43 of Set 15 | evensk
# Processing Record 44 of Set 15 | anage
# Processing Record 45 of Set 15 | ilam
# Processing Record 46 of Set 15 | baglan
# Processing Record 47 of Set 15 | keetmanshoop
# Processing Record 48 of Set 15 | den helder
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 685

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Duki  30.1541   68.5728     78.78        14          35
# 1   Provideniya  64.3833 -173.3000     31.84        89         100
# 2          Kaeo -35.1000  173.7833     62.33        60           8
# 3       Ushuaia -54.8000  -68.3000     38.86        70           0
# 4          Sola -13.8833  167.5500     83.07        84          75
# 5       Shimoda  34.6667  138.9500     62.96        78         100
# 6         Zabol  32.2500   67.2500     65.30        19           3
# 7      Jiangyou  31.7667  104.7167     67.05        69         100
# 8        Albany  42.6001  -73.9662     39.54        84          56
# 9  Punta Arenas -53.1500  -70.9167     41.11        70          14
#
#    Wind Speed Country Weather Description
# 0        3.58      PK    scattered clouds
# 1       15.82      RU     overcast clouds
# 2       10.16      NZ           clear sky
# 3        2.30      AR           clear sky
# 4        0.00      VU       broken clouds
# 5       14.70      JP     overcast clouds
# 6        7.67      AF           clear sky
# 7        2.28      CN     overcast clouds
# 8        1.97      US       broken clouds
# 9        8.05      CL          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Duki      PK  30.1541   68.5728     78.78        14          35
# 1  Provideniya      RU  64.3833 -173.3000     31.84        89         100
# 2         Kaeo      NZ -35.1000  173.7833     62.33        60           8
# 3      Ushuaia      AR -54.8000  -68.3000     38.86        70           0
# 4         Sola      VU -13.8833  167.5500     83.07        84          75
#
#    Wind Speed Weather Description
# 0        3.58    scattered clouds
# 1       15.82     overcast clouds
# 2       10.16           clear sky
# 3        2.30           clear sky
# 4        0.00       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="weather_data")
